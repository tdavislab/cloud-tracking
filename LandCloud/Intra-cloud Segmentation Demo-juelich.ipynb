# %%
from GWMT import *
import readMergeTree as rmt
import os
import networkx as nx
from matplotlib import pyplot as plt

# %% [markdown]
# # Load data
# * The simplified merge tree
# * The scalar field data

# %% [markdown]
# ## loading the merge tree and the scalar field data

# %%
datasets = ["20180501_juelich", "20180623_juelich", "20190512_juelich"]

# %%
maxima_only = True
# value_thres = 2.0

thres_dict_by_time = {
    "morning": 9,
    "afternoon": 10,
    "late-afternoon": 9
}

time_period = {
    "morning": [600, 900],  # 0, 36
    "afternoon": [901, 1500],  # 37, 108
    "late-afternoon": [1501, 1800],  # 109, 
}

def get_time_str(hrtime):
    int_hrtime = int(hrtime)
    for key in time_period:
        if (int_hrtime >= time_period[key][0]) and (int_hrtime <= time_period[key][1]):
            return key

def get_hrtime_by_filename(filename):
    fn1 = filename.replace(".txt", "").replace(".npy", "")
    datetime = fn1.split("_")[-1]
    date, hrtime = datetime.split("t")
    return hrtime

# gwmt_list = []

# mt_list = []
# root_list = []
# region_list = []
# value_list = []

gwmt_list = dict()

mt_list = dict()
root_list = dict()

time_list = dict()
period_list = dict()

datasets = ["20180501_juelich", "20180623_juelich", "20190512_juelich"]
for dataset in datasets:
    print("Working on", dataset)
    mt_list[dataset] = []
    root_list[dataset] = []
    
    time_list[dataset] = []
    period_list[dataset] = []
    
    dataset_path = os.path.join("data", dataset)
    for froot, di, files in os.walk(dataset_path):

        def key(s):
            try:
                int(s)
                return int(s)
            except ValueError:
                return len(files) + 1

        def isSegmentation(s: str):
            return "segmentation" in s

        def endsWithTxt(s: str):
            return s.endswith("txt")

        def endsWithNpy(s: str):
            return s.endswith("npy")

        txt_files = list(filter(endsWithTxt, files))
        txt_files.sort(key=lambda x: key(x.split(".")[0].split("_")[-1]))

        # You need to specify the root node type. Choices: ["minimum", "maximum"]
        # (Avoid specifying merge tree type to avoid confusion between split tree and join tree in different contexts)
        for file in txt_files:
            hrtime = get_hrtime_by_filename(file)
            value_thres = thres_dict_by_time[get_time_str(hrtime)]
            trees, roots = rmt.get_trees(os.path.join(dataset_path, file), root_type="minimum", threshold=value_thres)
            if len(trees) > 0:
                time_list[dataset].append(hrtime)
                period_list[dataset].append(get_time_str(hrtime))
            mt_list[dataset].extend(trees)
            root_list[dataset].extend(roots)

    assert (len(root_list[dataset]) == len(mt_list[dataset]))
    assert (len(time_list[dataset]) == len(mt_list[dataset]))
    assert (len(period_list[dataset]) == len(mt_list[dataset]))
    
# ================================================================== #
    
# Let's not oversimplify the merge tree, because now we need many nodes as anchor points

# This serves for removing the very-small cloud system from the results entirely
# This should be very small
disappear_volume_threshold = 1

# This is to reduce the number of anchor points (but not remove) for cloud systems
# This can be a bit large

def get_volume_thres(time_str):
    volume_thres_by_time_dict = {
        "morning": 5,
        "afternoon": 5,
        "late-afternoon": 5,
    }
    return volume_thres_by_time_dict[time_str]

simplified_mt_list = dict()
simplified_root_list = dict()

for dataset in datasets:
    print("Working on", dataset)
    simplified_mt_list[dataset] = [None for i in range(len(mt_list[dataset]))]
    simplified_root_list[dataset] = [None for i in range(len(mt_list[dataset]))]

    idx = 0

    for i in range(len(mt_list[dataset])):
        mt = mt_list[dataset][i]
        
        tstr = period_list[dataset][i]
        tt = time_list[dataset][i]
        value_thres = thres_dict_by_time[get_time_str(tt)]
        if True:
            _, simp_mt = volume_simplify_mt(mt, 
                                            vol_thres=get_volume_thres(tstr), 
                                            disappear_vol_thres=disappear_volume_threshold, 
                                            vol_name="volume", 
                                            stop_saddle_val=value_thres)
            simplified_mt_list[dataset][idx] = simp_mt
            simplified_root_list[dataset][idx] = simp_mt.root
        else:
            simplified_mt_list[dataset][idx] = mt
            simplified_root_list[dataset][idx] = mt.root

        nn_smaller_than_thres = 0
        for node in simplified_mt_list[dataset][idx].nodes():
            if simplified_mt_list[dataset][idx].nodes[node]["height"] < value_thres:
                if simplified_mt_list[dataset][idx].nodes[node]["type"] == 2:
                    nn_smaller_than_thres += 1
        print(tt, mt.number_of_nodes(), simplified_mt_list[dataset][idx].number_of_nodes(), nn_smaller_than_thres)
        idx += 1
# Out:
# Working on 20180501_juelich
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Working on 20180623_juelich
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Working on 20190512_juelich
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Adding volume to the merge tree
# Working on 20180501_juelich
# Initially removing 6350 leaves.
# 0600 15346 4032 0
# Initially removing 6415 leaves.
# 0605 15321 3767 0
# Initially removing 6324 leaves.
# 0610 15110 3700 0
# Initially removing 6370 leaves.
# 0615 15043 3573 0
# Initially removing 6250 leaves.
# 0620 14979 3679 0
# Initially removing 6117 leaves.
# 0625 14612 3591 0
# Initially removing 6130 leaves.
# 0630 14572 3524 0
# Initially removing 5955 leaves.
# 0635 14214 3458 0
# Initially removing 5834 leaves.
# 0640 13955 3408 0
# Initially removing 6152 leaves.
# 0645 14439 3299 0
# Initially removing 5917 leaves.
# 0650 14023 3277 0
# Initially removing 6096 leaves.
# 0655 14279 3243 0
# Initially removing 6097 leaves.
# 0700 14266 3218 0
# Initially removing 6130 leaves.
# 0705 14321 3162 0
# Initially removing 6081 leaves.
# 0710 14234 3186 0
# Initially removing 6114 leaves.
# 0715 14261 3124 0
# Initially removing 6077 leaves.
# 0720 14154 3155 0
# Initially removing 5997 leaves.
# 0725 13991 3104 0
# Initially removing 6115 leaves.
# 0730 14192 3059 0
# Initially removing 6158 leaves.
# 0735 14268 3103 0
# Initially removing 6144 leaves.
# 0740 14116 2950 0
# Initially removing 6163 leaves.
# 0745 14161 2973 0
# Initially removing 6106 leaves.
# 0750 14070 2909 0
# Initially removing 6118 leaves.
# 0755 14149 2975 0
# Initially removing 6149 leaves.
# 0800 14242 2992 0
# Initially removing 6315 leaves.
# 0805 14501 2930 0
# Initially removing 6309 leaves.
# 0810 14490 2936 0
# Initially removing 6431 leaves.
# 0815 14585 2831 0
# Initially removing 6306 leaves.
# 0820 14447 2838 0
# Initially removing 6461 leaves.
# 0825 14756 2872 0
# Initially removing 6467 leaves.
# 0830 14794 2867 0
# Initially removing 6526 leaves.
# 0835 14937 2834 0
# Initially removing 6589 leaves.
# 0840 15081 2885 0
# Initially removing 6507 leaves.
# 0845 14858 2831 0
# Initially removing 6490 leaves.
# 0850 14691 2572 0
# Initially removing 6690 leaves.
# 0855 15052 2509 0
# Initially removing 6662 leaves.
# 0900 15035 2488 0
# Initially removing 6778 leaves.
# 0905 15177 2466 0
# Initially removing 6713 leaves.
# 0910 15209 2598 0
# Initially removing 6611 leaves.
# 0915 15125 2746 0
# Initially removing 6594 leaves.
# 0920 15111 2793 0
# Initially removing 6646 leaves.
# 0925 15238 2846 0
# Initially removing 6661 leaves.
# 0930 15300 2861 0
# Initially removing 6585 leaves.
# 0935 15216 2942 0
# Initially removing 6469 leaves.
# 0940 15090 3025 0
# Initially removing 6635 leaves.
# 0945 15378 3000 0
# Initially removing 6618 leaves.
# 0950 15390 3008 0
# Initially removing 6589 leaves.
# 0955 15407 3054 0
# Initially removing 6663 leaves.
# 1000 15515 3055 0
# Initially removing 6657 leaves.
# 1005 15494 2978 0
# Initially removing 6570 leaves.
# 1010 15322 2960 0
# Initially removing 6662 leaves.
# 1015 15441 2930 0
# Initially removing 6521 leaves.
# 1020 15229 2974 0
# Initially removing 6587 leaves.
# 1025 15340 2979 0
# Initially removing 6602 leaves.
# 1030 15430 2987 0
# Initially removing 6733 leaves.
# 1035 15627 2930 0
# Initially removing 6713 leaves.
# 1040 15581 2926 0
# Initially removing 6788 leaves.
# 1045 15661 2864 0
# Initially removing 6642 leaves.
# 1050 15295 2831 0
# Initially removing 6733 leaves.
# 1055 15507 2848 0
# Initially removing 6609 leaves.
# 1100 15251 2798 0
# Initially removing 6597 leaves.
# 1105 15135 2689 0
# Initially removing 6625 leaves.
# 1110 15189 2686 0
# Initially removing 6657 leaves.
# 1115 15239 2708 0
# Initially removing 6576 leaves.
# 1120 15121 2691 0
# Initially removing 6523 leaves.
# 1125 14999 2649 0
# Initially removing 6557 leaves.
# 1130 14914 2504 0
# Initially removing 6420 leaves.
# 1135 14736 2514 0
# Initially removing 6441 leaves.
# 1140 14777 2554 0
# Initially removing 6448 leaves.
# 1145 14744 2520 0
# Initially removing 6515 leaves.
# 1150 14881 2512 0
# Initially removing 6523 leaves.
# 1155 14903 2525 0
# Initially removing 6541 leaves.
# 1200 14965 2514 0
# Initially removing 6516 leaves.
# 1205 14827 2487 0
# Initially removing 6411 leaves.
# 1210 14717 2506 0
# Initially removing 6515 leaves.
# 1215 14830 2436 0
# Initially removing 6492 leaves.
# 1220 14836 2481 0
# Initially removing 6431 leaves.
# 1225 14713 2539 0
# Initially removing 6400 leaves.
# 1230 14715 2555 0
# Initially removing 6344 leaves.
# 1235 14596 2548 0
# Initially removing 6375 leaves.
# 1240 14681 2599 0
# Initially removing 6335 leaves.
# 1245 14590 2615 0
# Initially removing 6297 leaves.
# 1250 14455 2514 0
# Initially removing 6172 leaves.
# 1255 14204 2482 0
# Initially removing 6178 leaves.
# 1300 14180 2477 0
# Initially removing 6198 leaves.
# 1305 14143 2393 0
# Initially removing 6044 leaves.
# 1310 13850 2346 0
# Initially removing 6095 leaves.
# 1315 13870 2298 0
# Initially removing 6209 leaves.
# 1320 14116 2276 0
# Initially removing 6208 leaves.
# 1325 14086 2235 0
# Initially removing 6313 leaves.
# 1330 14314 2254 0
# Initially removing 6170 leaves.
# 1335 14080 2331 0
# Initially removing 6022 leaves.
# 1340 13799 2346 0
# Initially removing 6024 leaves.
# 1345 14006 2638 0
# Initially removing 6094 leaves.
# 1350 14153 2702 0
# Initially removing 5963 leaves.
# 1355 13924 2705 0
# Initially removing 6025 leaves.
# 1400 13946 2588 0
# Initially removing 5842 leaves.
# 1405 13633 2560 0
# Initially removing 5946 leaves.
# 1410 13691 2424 0
# Initially removing 5846 leaves.
# 1415 13584 2437 0
# Initially removing 5855 leaves.
# 1420 13495 2333 0
# Initially removing 5886 leaves.
# 1425 13593 2315 0
# Initially removing 5918 leaves.
# 1430 13562 2234 0
# Initially removing 5862 leaves.
# 1435 13428 2192 0
# Initially removing 5934 leaves.
# 1440 13528 2220 0
# Initially removing 5901 leaves.
# 1445 13530 2247 0
# Initially removing 5928 leaves.
# 1450 13563 2216 0
# Initially removing 5937 leaves.
# 1455 13567 2208 0
# Initially removing 5934 leaves.
# 1500 13566 2207 0
# Initially removing 5789 leaves.
# 1505 13332 2329 0
# Initially removing 5834 leaves.
# 1510 13389 2276 0
# Initially removing 5833 leaves.
# 1515 13377 2280 0
# Initially removing 5719 leaves.
# 1520 13128 2220 0
# Initially removing 5667 leaves.
# 1525 13067 2255 0
# Initially removing 5685 leaves.
# 1530 13104 2258 0
# Initially removing 5572 leaves.
# 1535 12874 2251 0
# Initially removing 5637 leaves.
# 1540 12921 2157 0
# Initially removing 5419 leaves.
# 1545 12539 2222 0
# Initially removing 5427 leaves.
# 1550 12472 2180 0
# Initially removing 5288 leaves.
# 1555 12354 2267 0
# Initially removing 5327 leaves.
# 1600 12307 2142 0
# Initially removing 5324 leaves.
# 1605 12229 2091 0
# Initially removing 5356 leaves.
# 1610 12335 2137 0
# Initially removing 5244 leaves.
# 1615 11970 2001 0
# Initially removing 5163 leaves.
# 1620 11777 1916 0
# Initially removing 5132 leaves.
# 1625 11688 1837 0
# Initially removing 5108 leaves.
# 1630 11638 1853 0
# Initially removing 5099 leaves.
# 1635 11557 1785 0
# Initially removing 4970 leaves.
# 1640 11263 1765 0
# Initially removing 4958 leaves.
# 1645 11153 1638 0
# Initially removing 4747 leaves.
# 1650 10713 1606 0
# Initially removing 4662 leaves.
# 1655 10519 1546 0
# Initially removing 4773 leaves.
# 1700 10689 1535 0
# Initially removing 4737 leaves.
# 1705 10638 1505 0
# Initially removing 4662 leaves.
# 1710 10489 1480 0
# Initially removing 4741 leaves.
# 1715 10588 1462 0
# Initially removing 4587 leaves.
# 1720 10270 1415 0
# Initially removing 4579 leaves.
# 1725 10230 1400 0
# Initially removing 4488 leaves.
# 1730 10027 1350 0
# Initially removing 4487 leaves.
# 1735 9951 1302 0
# Initially removing 4253 leaves.
# 1740 9523 1313 0
# Initially removing 4388 leaves.
# 1745 9681 1240 0
# Working on 20180623_juelich
# Initially removing 4209 leaves.
# 0600 9766 1824 0
# Initially removing 4127 leaves.
# 0605 9590 1822 0
# Initially removing 4207 leaves.
# 0610 9693 1754 0
# Initially removing 4184 leaves.
# 0615 9614 1704 0
# Initially removing 4370 leaves.
# 0620 9929 1632 0
# Initially removing 4228 leaves.
# 0625 9685 1651 0
# Initially removing 4331 leaves.
# 0630 9867 1656 0
# Initially removing 4394 leaves.
# 0635 9974 1625 0
# Initially removing 4289 leaves.
# 0640 9789 1608 0
# Initially removing 4365 leaves.
# 0645 9905 1610 0
# Initially removing 4411 leaves.
# 0650 10033 1642 0
# Initially removing 4482 leaves.
# 0655 10243 1712 0
# Initially removing 4503 leaves.
# 0700 10251 1716 0
# Initially removing 4593 leaves.
# 0705 10525 1778 0
# Initially removing 4679 leaves.
# 0710 10656 1790 0
# Initially removing 4696 leaves.
# 0715 10718 1866 0
# Initially removing 4747 leaves.
# 0720 10859 1893 0
# Initially removing 4707 leaves.
# 0725 10818 1895 0
# Initially removing 4825 leaves.
# 0730 11049 1924 0
# Initially removing 4817 leaves.
# 0735 11037 1944 0
# Initially removing 5027 leaves.
# 0740 11461 1957 0
# Initially removing 4911 leaves.
# 0745 11273 1972 0
# Initially removing 4964 leaves.
# 0750 11289 1905 0
# Initially removing 4970 leaves.
# 0755 11370 1944 0
# Initially removing 5055 leaves.
# 0800 11547 1980 0
# Initially removing 4863 leaves.
# 0805 11289 2082 0
# Initially removing 4843 leaves.
# 0810 11246 2142 0
# Initially removing 4857 leaves.
# 0815 11282 2180 0
# Initially removing 4762 leaves.
# 0820 11153 2136 0
# Initially removing 4838 leaves.
# 0825 11374 2278 0
# Initially removing 4801 leaves.
# 0830 11352 2284 0
# Initially removing 4783 leaves.
# 0835 11275 2351 0
# Initially removing 4831 leaves.
# 0840 11403 2344 0
# Initially removing 4909 leaves.
# 0845 11504 2335 0
# Initially removing 4879 leaves.
# 0850 11519 2429 0
# Initially removing 4915 leaves.
# 0855 11617 2421 0
# Initially removing 4956 leaves.
# 0900 11831 2547 0
# Initially removing 5081 leaves.
# 0905 11870 2383 0
# Initially removing 5105 leaves.
# 0910 11918 2352 0
# Initially removing 5046 leaves.
# 0915 11710 2237 0
# Initially removing 4975 leaves.
# 0920 11472 2106 0
# Initially removing 5233 leaves.
# 0925 11932 2050 0
# Initially removing 5222 leaves.
# 0930 11862 1957 0
# Initially removing 5359 leaves.
# 0935 12169 2000 0
# Initially removing 5421 leaves.
# 0940 12272 2032 0
# Initially removing 5094 leaves.
# 0945 11666 2016 0
# Initially removing 4862 leaves.
# 0950 11223 2065 0
# Initially removing 4859 leaves.
# 0955 11133 2003 0
# Initially removing 4918 leaves.
# 1000 11341 2064 0
# Initially removing 4775 leaves.
# 1005 11057 2064 0
# Initially removing 4887 leaves.
# 1010 11240 2069 0
# Initially removing 4793 leaves.
# 1015 11061 1982 0
# Initially removing 4842 leaves.
# 1020 11110 2003 0
# Initially removing 4829 leaves.
# 1025 11195 2125 0
# Initially removing 4936 leaves.
# 1030 11317 2036 0
# Initially removing 4943 leaves.
# 1035 11356 2027 0
# Initially removing 4909 leaves.
# 1040 11311 2001 0
# Initially removing 4905 leaves.
# 1045 11269 1944 0
# Initially removing 4820 leaves.
# 1050 11080 1960 0
# Initially removing 4857 leaves.
# 1055 11188 1991 0
# Initially removing 4844 leaves.
# 1100 11168 1992 0
# Initially removing 4940 leaves.
# 1105 11340 2018 0
# Initially removing 4937 leaves.
# 1110 11329 2026 0
# Initially removing 4938 leaves.
# 1115 11295 1953 0
# Initially removing 4911 leaves.
# 1120 11257 1912 0
# Initially removing 4831 leaves.
# 1125 11071 1930 0
# Initially removing 4969 leaves.
# 1130 11328 1942 0
# Initially removing 4892 leaves.
# 1135 11212 1952 0
# Initially removing 4916 leaves.
# 1140 11322 2000 0
# Initially removing 5035 leaves.
# 1145 11512 1967 0
# Initially removing 5077 leaves.
# 1150 11555 1946 0
# Initially removing 5077 leaves.
# 1155 11585 1929 0
# Initially removing 4942 leaves.
# 1200 11251 1867 0
# Initially removing 5087 leaves.
# 1205 11532 1891 0
# Initially removing 5114 leaves.
# 1210 11613 1895 0
# Initially removing 5069 leaves.
# 1215 11595 1928 0
# Initially removing 5197 leaves.
# 1220 11809 1901 0
# Initially removing 5104 leaves.
# 1225 11672 1949 0
# Initially removing 5198 leaves.
# 1230 11848 1968 0
# Initially removing 5115 leaves.
# 1235 11677 1967 0
# Initially removing 5280 leaves.
# 1240 12003 2003 0
# Initially removing 5222 leaves.
# 1245 11980 2093 0
# Initially removing 5288 leaves.
# 1250 12035 2012 0
# Initially removing 5496 leaves.
# 1255 12423 2042 0
# Initially removing 5497 leaves.
# 1300 12574 2091 0
# Initially removing 5492 leaves.
# 1305 12507 2020 0
# Initially removing 5611 leaves.
# 1310 12755 2074 0
# Initially removing 5557 leaves.
# 1315 12606 2073 0
# Initially removing 5399 leaves.
# 1320 12423 2146 0
# Initially removing 5495 leaves.
# 1325 12720 2274 0
# Initially removing 5683 leaves.
# 1330 13050 2312 0
# Initially removing 5649 leaves.
# 1335 13083 2391 0
# Initially removing 5771 leaves.
# 1340 13232 2300 0
# Initially removing 5768 leaves.
# 1345 13248 2306 0
# Initially removing 5796 leaves.
# 1350 13338 2353 0
# Initially removing 5884 leaves.
# 1355 13417 2243 0
# Initially removing 5876 leaves.
# 1400 13379 2237 0
# Initially removing 6001 leaves.
# 1405 13714 2265 0
# Initially removing 5938 leaves.
# 1410 13659 2320 0
# Initially removing 6091 leaves.
# 1415 13892 2289 0
# Initially removing 5992 leaves.
# 1420 13757 2286 0
# Initially removing 5896 leaves.
# 1425 13615 2301 0
# Initially removing 5954 leaves.
# 1430 13688 2313 0
# Initially removing 6078 leaves.
# 1435 13921 2335 0
# Initially removing 6063 leaves.
# 1440 13893 2322 0
# Initially removing 6143 leaves.
# 1445 14079 2351 0
# Initially removing 6188 leaves.
# 1450 14043 2283 0
# Initially removing 6221 leaves.
# 1455 14147 2323 0
# Initially removing 6061 leaves.
# 1500 13939 2384 0
# Initially removing 6082 leaves.
# 1505 14026 2503 0
# Initially removing 6096 leaves.
# 1510 14016 2466 0
# Initially removing 6035 leaves.
# 1515 13915 2451 0
# Initially removing 5958 leaves.
# 1520 13809 2497 0
# Initially removing 6120 leaves.
# 1525 13992 2383 0
# Initially removing 6065 leaves.
# 1530 14032 2483 0
# Initially removing 6045 leaves.
# 1535 13941 2503 0
# Initially removing 6117 leaves.
# 1540 14043 2474 0
# Initially removing 6101 leaves.
# 1545 14125 2517 0
# Initially removing 6171 leaves.
# 1550 14078 2376 0
# Initially removing 6232 leaves.
# 1555 14233 2392 0
# Initially removing 6258 leaves.
# 1600 14259 2411 0
# Initially removing 6216 leaves.
# 1605 14227 2425 0
# Initially removing 6242 leaves.
# 1610 14223 2377 0
# Initially removing 6319 leaves.
# 1615 14384 2368 0
# Initially removing 6364 leaves.
# 1620 14468 2375 0
# Initially removing 6301 leaves.
# 1625 14300 2361 0
# Initially removing 6350 leaves.
# 1630 14373 2363 0
# Initially removing 6388 leaves.
# 1635 14380 2237 0
# Initially removing 6393 leaves.
# 1640 14375 2218 0
# Initially removing 6427 leaves.
# 1645 14494 2214 0
# Initially removing 6380 leaves.
# 1650 14373 2194 0
# Initially removing 6397 leaves.
# 1655 14384 2191 0
# Initially removing 6373 leaves.
# 1700 14289 2170 0
# Initially removing 6321 leaves.
# 1705 14257 2196 0
# Initially removing 6498 leaves.
# 1710 14582 2256 0
# Initially removing 6436 leaves.
# 1715 14443 2221 0
# Initially removing 6418 leaves.
# 1720 14491 2286 0
# Initially removing 6435 leaves.
# 1725 14474 2246 0
# Initially removing 6335 leaves.
# 1730 14328 2288 0
# Initially removing 6214 leaves.
# 1735 14111 2292 0
# Initially removing 6268 leaves.
# 1740 14194 2205 0
# Initially removing 6183 leaves.
# 1745 14043 2242 0
# Initially removing 6047 leaves.
# 1750 13888 2331 0
# Initially removing 6178 leaves.
# 1755 14044 2258 0
# Working on 20190512_juelich
# Initially removing 831 leaves.
# 0600 2965 1438 0
# Initially removing 890 leaves.
# 0605 3015 1441 0
# Initially removing 845 leaves.
# 0610 2941 1398 0
# Initially removing 884 leaves.
# 0615 2963 1362 0
# Initially removing 935 leaves.
# 0620 3090 1401 0
# Initially removing 873 leaves.
# 0625 3056 1474 0
# Initially removing 884 leaves.
# 0630 3089 1498 0
# Initially removing 952 leaves.
# 0635 3202 1515 0
# Initially removing 932 leaves.
# 0640 3258 1598 0
# Initially removing 932 leaves.
# 0645 3280 1597 0
# Initially removing 990 leaves.
# 0650 3420 1670 0
# Initially removing 981 leaves.
# 0655 3483 1734 0
# Initially removing 1010 leaves.
# 0700 3538 1755 0
# Initially removing 1014 leaves.
# 0705 3622 1814 0
# Initially removing 1119 leaves.
# 0710 3844 1876 0
# Initially removing 1146 leaves.
# 0715 3967 1912 0
# Initially removing 1254 leaves.
# 0720 4237 1981 0
# Initially removing 1214 leaves.
# 0725 4335 2183 0
# Initially removing 1338 leaves.
# 0730 4702 2327 0
# Initially removing 1372 leaves.
# 0735 4816 2381 0
# Initially removing 1418 leaves.
# 0740 5020 2511 0
# Initially removing 1488 leaves.
# 0745 5343 2701 0
# Initially removing 1538 leaves.
# 0750 5446 2739 0
# Initially removing 1596 leaves.
# 0755 5607 2784 0
# Initially removing 1628 leaves.
# 0800 5770 2881 0
# Initially removing 1622 leaves.
# 0805 5805 2912 0
# Initially removing 1631 leaves.
# 0810 5855 2971 0
# Initially removing 1680 leaves.
# 0815 5983 3044 0
# Initially removing 1684 leaves.
# 0820 6048 3084 0
# Initially removing 1712 leaves.
# 0825 6155 3145 0
# Initially removing 1742 leaves.
# 0830 6291 3275 0
# Initially removing 1791 leaves.
# 0835 6418 3273 0
# Initially removing 1939 leaves.
# 0840 6746 3321 0
# Initially removing 1959 leaves.
# 0845 6849 3335 0
# Initially removing 1816 leaves.
# 0850 6422 3172 0
# Initially removing 1559 leaves.
# 0855 5587 2757 0
# Initially removing 1483 leaves.
# 0900 5225 2477 0
# Initially removing 1577 leaves.
# 0905 5156 2251 0
# Initially removing 1590 leaves.
# 0910 5186 2263 0
# Initially removing 1598 leaves.
# 0915 5241 2291 0
# Initially removing 1546 leaves.
# 0920 5164 2332 0
# Initially removing 1483 leaves.
# 0925 5163 2443 0
# Initially removing 1450 leaves.
# 0930 5082 2423 0
# Initially removing 1543 leaves.
# 0935 5304 2548 0
# Initially removing 1557 leaves.
# 0940 5271 2449 0
# Initially removing 1585 leaves.
# 0945 5324 2470 0
# Initially removing 1567 leaves.
# 0950 5298 2488 0
# Initially removing 1531 leaves.
# 0955 5246 2497 0
# Initially removing 1567 leaves.
# 1000 5269 2415 0
# Initially removing 1508 leaves.
# 1005 5139 2370 0
# Initially removing 1586 leaves.
# 1010 5172 2296 0
# Initially removing 1572 leaves.
# 1015 5129 2264 0
# Initially removing 1526 leaves.
# 1020 5127 2371 0
# Initially removing 1485 leaves.
# 1025 5026 2322 0
# Initially removing 1519 leaves.
# 1030 5040 2274 0
# Initially removing 1527 leaves.
# 1035 5042 2276 0
# Initially removing 1494 leaves.
# 1040 5006 2284 0
# Initially removing 1512 leaves.
# 1045 4992 2249 0
# Initially removing 1481 leaves.
# 1050 4962 2279 0
# Initially removing 1433 leaves.
# 1055 4824 2200 0
# Initially removing 1477 leaves.
# 1100 4832 2134 0
# Initially removing 1452 leaves.
# 1105 4862 2213 0
# Initially removing 1471 leaves.
# 1110 4929 2209 0
# Initially removing 1459 leaves.
# 1115 4913 2218 0
# Initially removing 1461 leaves.
# 1120 4876 2199 0
# Initially removing 1434 leaves.
# 1125 4883 2238 0
# Initially removing 1482 leaves.
# 1130 4937 2219 0
# Initially removing 1506 leaves.
# 1135 4920 2170 0
# Initially removing 1443 leaves.
# 1140 4875 2186 0
# Initially removing 1503 leaves.
# 1145 4902 2112 0
# Initially removing 1485 leaves.
# 1150 4888 2111 0
# Initially removing 1492 leaves.
# 1155 4892 2111 0
# Initially removing 1509 leaves.
# 1200 4856 2048 0
# Initially removing 1521 leaves.
# 1205 4852 2017 0
# Initially removing 1540 leaves.
# 1210 4957 2081 0
# Initially removing 1530 leaves.
# 1215 4967 2084 0
# Initially removing 1589 leaves.
# 1220 5077 2086 0
# Initially removing 1579 leaves.
# 1225 5059 2116 0
# Initially removing 1557 leaves.
# 1230 5014 2091 0
# Initially removing 1571 leaves.
# 1235 5048 2095 0
# Initially removing 1585 leaves.
# 1240 5077 2119 0
# Initially removing 1565 leaves.
# 1245 4961 2041 0
# Initially removing 1582 leaves.
# 1250 5022 2057 0
# Initially removing 1599 leaves.
# 1255 5089 2106 0
# Initially removing 1620 leaves.
# 1300 5141 2100 0
# Initially removing 1632 leaves.
# 1305 5197 2134 0
# Initially removing 1596 leaves.
# 1310 5094 2090 0
# Initially removing 1533 leaves.
# 1315 4975 2066 0
# Initially removing 1548 leaves.
# 1320 5074 2164 0
# Initially removing 1517 leaves.
# 1325 5052 2217 0
# Initially removing 1563 leaves.
# 1330 5259 2342 0
# Initially removing 1680 leaves.
# 1335 5694 2632 0
# Initially removing 1835 leaves.
# 1340 6395 3016 0
# Initially removing 1826 leaves.
# 1345 6485 3165 0
# Initially removing 1674 leaves.
# 1350 6136 3102 0
# Initially removing 1494 leaves.
# 1355 5733 2990 0
# Initially removing 1503 leaves.
# 1400 5663 2898 0
# Initially removing 1507 leaves.
# 1405 5637 2848 0
# Initially removing 1446 leaves.
# 1410 5549 2885 0
# Initially removing 1421 leaves.
# 1415 5437 2865 0
# Initially removing 1401 leaves.
# 1420 5311 2722 0
# Initially removing 1430 leaves.
# 1425 5345 2741 0
# Initially removing 1416 leaves.
# 1430 5244 2673 0
# Initially removing 1365 leaves.
# 1435 5119 2627 0
# Initially removing 1356 leaves.
# 1440 5071 2618 0
# Initially removing 1344 leaves.
# 1445 5068 2651 0
# Initially removing 1340 leaves.
# 1450 5009 2588 0
# Initially removing 1301 leaves.
# 1455 4962 2618 0
# Initially removing 1246 leaves.
# 1500 4850 2584 0
# Initially removing 1188 leaves.
# 1505 4772 2673 0
# Initially removing 1167 leaves.
# 1510 4698 2628 0
# Initially removing 1191 leaves.
# 1515 4618 2526 0
# Initially removing 1189 leaves.
# 1520 4561 2468 0
# Initially removing 1145 leaves.
# 1525 4435 2444 0
# Initially removing 1094 leaves.
# 1530 4325 2382 0
# Initially removing 1042 leaves.
# 1535 4157 2348 0
# Initially removing 1008 leaves.
# 1540 4005 2252 0
# Initially removing 1097 leaves.
# 1545 4037 2118 0
# Initially removing 1009 leaves.
# 1550 3834 2036 0
# Initially removing 993 leaves.
# 1555 3737 1988 0
# Initially removing 1016 leaves.
# 1600 3693 1901 0
# Initially removing 989 leaves.
# 1605 3629 1864 0
# Initially removing 955 leaves.
# 1610 3525 1835 0
# Initially removing 985 leaves.
# 1615 3464 1724 0
# Initially removing 975 leaves.
# 1620 3371 1640 0
# Initially removing 953 leaves.
# 1625 3271 1582 0
# Initially removing 856 leaves.
# 1630 3068 1524 0
# Initially removing 813 leaves.
# 1635 2906 1469 0
# Initially removing 801 leaves.
# 1640 2778 1374 0
# Initially removing 752 leaves.
# 1645 2673 1334 0
# Initially removing 767 leaves.
# 1650 2604 1258 0
# Initially removing 754 leaves.
# 1655 2526 1194 0
# Initially removing 709 leaves.
# 1700 2427 1160 0
# Initially removing 700 leaves.
# 1705 2331 1096 0
# Initially removing 696 leaves.
# 1710 2309 1072 0
# Initially removing 646 leaves.
# 1715 2177 1026 0
# Initially removing 603 leaves.
# 1720 2069 1002 0
# Initially removing 572 leaves.
# 1725 1942 932 0
# Initially removing 568 leaves.
# 1730 1908 918 0
# Initially removing 584 leaves.
# 1735 1852 863 0
# Initially removing 544 leaves.
# 1740 1765 830 0
# Initially removing 543 leaves.
# 1745 1756 814 0
# Initially removing 512 leaves.
# 1750 1672 757 0
# Initially removing 489 leaves.
# 1755 1586 723 0

# %% [markdown]
# ## Apply area-based intra-cloud anchor point simplification

# %%
# # Let's not oversimplify the merge tree, because now we need many nodes as anchor points

# # This serves for removing the very-small cloud system from the results entirely
# # This should be very small
# disappear_volume_threshold = 10

# # This is to reduce the number of anchor points (but not remove) for cloud systems
# # This can be a bit large
# volume_threshold = 30

# simplified_mt_list = [None for i in range(len(mt_list))]
# simplified_root_list = [None for i in range(len(mt_list))]

# idx = 0

# for mt, region in zip(mt_list, region_list):
#     if volume_threshold > 0:
#         _, simp_mt = volume_simplify_mt(mt, 
#                                         vol_thres=volume_threshold, 
#                                         disappear_vol_thres=disappear_volume_threshold, 
#                                         vol_name="volume", 
#                                         stop_saddle_val=value_thres)
#         simplified_mt_list[idx] = simp_mt
#         simplified_root_list[idx] = simp_mt.root
#     else:
#         simplified_mt_list[idx] = mt
#         simplified_root_list[idx] = mt.root
#     print(mt.number_of_nodes(), simplified_mt_list[idx].number_of_nodes())
#     idx += 1

# %% [markdown]
# ## We save all the remaining critical point information as a list
#
# - Key information: "x", "y", "z", "CriticalType"

# %%
cp_info_root = "./simplified-merge-trees/"

for dataset in datasets:
    cp_info_dir = os.path.join(cp_info_root, dataset)
    os.makedirs(cp_info_dir, exist_ok=True)

    for em, mt in enumerate(simplified_mt_list[dataset]):
        crit_pts = []
        for node in mt.nodes():
            crit_pts.append([mt.nodes[node]["x"], mt.nodes[node]["y"], mt.nodes[node]["z"], mt.nodes[node]["height"], mt.nodes[node]["type"]])
        cp_file = os.path.join(cp_info_dir, "treeNodes_{}.txt".format(str(em).zfill(3)))
        with open(cp_file, "w") as outf:
            for x, y, z, height, tp in crit_pts:
                print(int(x), int(y), int(z), height, int(tp), file=outf)
    #     crit_pts = np.asarray(crit_pts, dtype=int)
    #     np.savetxt(cp_file, crit_pts, fmt="%d")

        edges = []
        for node in mt.nodes():
            for neighbor in mt.neighbors(node):
                assert node < mt.number_of_nodes()
                if neighbor > node:
                    edges.append([node, neighbor])
        edge_file = os.path.join(cp_info_dir, "treeEdges_{}.txt".format(str(em).zfill(3)))
        edges = np.asarray(edges, dtype=int)

        assert len(edges) == len(crit_pts) - 1
        np.savetxt(edge_file, edges, fmt="%d")

# %% [markdown]
# ## We put all anchor points at a time step into a list for future use

# %%
# anchor_points_list = []

# for mt in simplified_mt_list:
#     anchor_pts = []
#     for node in mt.nodes():
#         if mt.nodes[node]["type"] == 2:
#             anchor_pts.append({"id":node, "x":mt.nodes[node]["x"], "y":mt.nodes[node]["y"]})
#     anchor_points_list.append(anchor_pts)

# %% [markdown]
# # Watershed Segmentation

# %%
# from skimage.segmentation import watershed

# %% [markdown]
# First, we visualize all the cloud areas above the superlevel set threshold

# %%
# # value_thres = 2.0
# time_i = 10

# %%
# scalar_field = value_list[time_i]
# anchor_points = anchor_points_list[time_i]

# %%
# binary_map = np.zeros(scalar_field.shape)
# binary_map[scalar_field >= value_thres] = 1

# %%
# plt.imshow(binary_map, interpolation="none")
# plt.colorbar()

# %%
# ## Watershed tests

# # markers are the coordinates from anchor points, but must be INT
# markers = np.asarray([[int(each["x"]), int(each["y"])] for each in anchor_points], dtype=int)
# print(markers.shape, np.max(markers[:, 0]), np.max(markers[:, 1]))
# print(scalar_field.shape)
                    
# plt.imshow(binary_map, interpolation="none")
# plt.scatter(x=markers[:, 1], 
#             y=markers[:, 0],
#             s=2)
# plt.colorbar()

# %%
# from scipy.ndimage import label
# markers_in_field = np.zeros(scalar_field.shape, dtype=bool)
# markers_in_field[tuple(markers.T)] = True
# markers_with_label, _ = label(markers_in_field, structure=np.asarray([[0, 0, 0],[0, 1, 0],[0, 0, 0]]))

# labels = watershed(-scalar_field, markers=markers_with_label, connectivity=2, mask=binary_map)

# plt.figure(figsize=(16, 10))
# plt.imshow(labels, interpolation="none")
# plt.colorbar()
# plt.scatter(x=markers[:, 1], 
#             y=markers[:, 0],
#             s=2,
#             c="r")

# %%
# plt.figure(figsize=(16, 10))
# plt.imshow(markers_with_label, interpolation="none")
# plt.colorbar()
# # plt.scatter(x=markers[:, 1], 
# #             y=markers[:, 0],
# #             s=2,
# #             c="r")

# %% [markdown]
# We briefly report some statistics to this segmentation

# %%
# label_index, label_counts = np.unique(labels, return_counts=True)

# print(len(markers))
# print(np.sum(markers_in_field))
# print(np.max(markers_with_label))

# %%
# mlabel_index, mlabel_counts = np.unique(markers_with_label, return_counts=True)
# print(len(mlabel_counts))

# %% [markdown]
# ### The histogram for the segmentation area.
#
# A majority of cloud segmentations are small in area, but there are also regions with >6000 pixels in area.
# It casts doubt on whether using the area as the probability is stable, because the range of the probability of nodes can be very large. (e.g., 6000:10)

# %%
# plt.hist(label_counts[1:], bins=200)
# plt.show()

# %% [markdown]
# ### Unit-based probability distribution
#
# We distribute a total probability of 1 to all anchor points based on the area of the segmentation.
# Therefore, the probability assigned to a node is (seg_area) * 1/(total_cloud_area),
#
# The 1/(total_cloud_area) is the unit for the probability in this case.
#
# Notes for total cloud area:
# * time_0: 281231
# * time_1: 250313
# * time_2: 245292

# %%
# print("Total cloud area:", np.sum(label_counts[1:]))

# %% [markdown]
# ## Pairwise Region distance

# %%
# time_j = time_i + 1
# print(time_i, time_j)

# %%
# def get_segmentation(t):
#     scalar_field = value_list[t]
#     anchor_points = anchor_points_list[t]
    
#     binary_map = np.zeros(scalar_field.shape)
#     binary_map[scalar_field >= value_thres] = 1
    
#     markers = np.asarray([[int(each["x"]), int(each["y"])] for each in anchor_points], dtype=int)
#     markers_in_field = np.zeros(scalar_field.shape, dtype=bool)
#     markers_in_field[tuple(markers.T)] = True
#     markers_with_label, _ = label(markers_in_field, structure=np.asarray([[0, 0, 0],[0, 1, 0],[0, 0, 0]]))

#     labels = watershed(-scalar_field, markers=markers_with_label, connectivity=2, mask=binary_map)
#     return labels

# %%
# seg_i = get_segmentation(time_i)
# seg_j = get_segmentation(time_j)

# %%
# dist_ij = segmentation_distance(seg_i, seg_j, max_dist=18, normalize_factor=932, max_workers=7)

# %%
# plt.imshow(dist_ij)

# %%
# ## Let's try some example filtering
# feature_i = np.random.randint(len(label_counts[1:])) + 1 # np.argmax(label_counts[1:]) + 1
# feature_i_map = np.zeros(seg_i.shape)
# feature_i_map[seg_i == feature_i] = 1

# feature_j_map = np.zeros(seg_j.shape)

# idx_i = feature_i - 1
# for idx_j in range(dist_ij.shape[1]):
#     feature_j = idx_j + 1
#     if dist_ij[idx_i, idx_j] < 932:
#         feature_j_map[seg_j == feature_j] = 10 + dist_ij[idx_i, idx_j]

# plt.figure(figsize=(18, 12))
# plt.subplot(211)
# plt.imshow(feature_i_map)

# plt.subplot(212)
# plt.imshow(feature_j_map)
